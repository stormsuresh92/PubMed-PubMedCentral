# %%
import requests
from bs4 import BeautifulSoup
import time

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'retry-After':'3600',
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'en-US,en;q=0.9',
    'Cache-Control':'max-age=0'
}

# %%
urls = ['https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5841432/','https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/', 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7599940/']
for url in urls:
  try:
    r = requests.get(url, headers=headers, timeout=5)
    soup = BeautifulSoup(r.content, 'html.parser')
    supps = soup.find(id='data-suppmats')
    count = 0
    for supp in supps:
      u = 'https://www.ncbi.nlm.nih.gov'+supp.find('a')['href']
      count +=1
      print(u)
  except:
    print('no supplementary file found')

  time.sleep(5)
# Out:
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5841432/bin/41420_2017_7_MOESM1_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5841432/bin/41420_2017_7_MOESM2_ESM.docx
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM1_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM2_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM3_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM4_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM5_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM6_ESM.tif
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM7_ESM.xlsx
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM8_ESM.docx
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8481293/bin/41418_2021_820_MOESM9_ESM.xlsx
# ...

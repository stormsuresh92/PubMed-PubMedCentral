# %%
import requests
import time

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'retry-After':'3600',
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'en-US,en;q=0.9',
    'Cache-Control':'max-age=0'
}

# %%
urls = open('pmcur.txt', 'r')
urlss = urls.readlines()
for k, url in enumerate(urlss):
  try:
    #start = time.time()
    url = url.strip()
    r = requests.get(url, headers=headers, timeout=5, allow_redirects=True)
    pdfurl = r.url
    #print(pdfurl)
    pdfname = pdfurl.split('/')[-3]
    with open(pdfname+'.pdf', 'wb') as f:
      res = requests.get(pdfurl, headers=headers, timeout=5, stream=True)
      if res.status_code ==200:
        f.write(res.content)
        #end = time.time()
        print(f"{k} {pdfname}: {res.status_code} sucessfully downloaded")
      else:
        print(f"{k} {pdfname}: {res.status_code} not sucessfully downloaded")
  except:
    pass

  time.sleep(2)
# Out:
# 0 PMC7118120: 200 sucessfully downloaded - time taken by 2
# 1 PMC9694842: 200 sucessfully downloaded - time taken by 3
# 2 PMC9405177: 200 sucessfully downloaded - time taken by 4
# 3 PMC9740098: 404 not sucessfully downloaded - time taken by -2.006537675857544
# 4 PMC6888615: 200 sucessfully downloaded - time taken by 2

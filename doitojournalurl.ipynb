# %%
import requests


headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

# %%
urls = open('doi.txt', 'r')
urlss = urls.readlines()
for url in urlss:
  r = requests.get(url.strip())
  print(r.url)
# Out:
# https://www.mdpi.com/1422-0067/19/4/1072
# https://www.nature.com/articles/s41418-021-00820-0
# https://www.mdpi.com/1422-0067/21/17/6007
# https://www.mdpi.com/1422-0067/21/17/6301
# https://www.nature.com/articles/s41420-017-0007-4
# https://www.mdpi.com/1999-4915/12/10/1139
# https://www.mdpi.com/1424-8247/16/2/276
# https://www.mdpi.com/2075-163X/11/2/138
# https://www.mdpi.com/1999-4923/13/4/493
# https://www.mdpi.com/2073-4441/11/1/96
# https://www.mdpi.com/2073-4441/13/1/38
# https://www.nature.com/articles/s41598-020-64503-5
